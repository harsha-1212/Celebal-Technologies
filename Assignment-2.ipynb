# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def add_node(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            print(f"Added head: {data}")
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            print(f"Added: {data}")

    def print_list(self):
        if self.head is None:
            print("List is empty.")
            return
        current = self.head
        print("Linked List:", end=" ")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

    def delete_nth_node(self, n):
        try:
            if self.head is None:
                raise IndexError("Cannot delete from an empty list.")
            if n < 1:
                raise IndexError("Invalid index. Must be 1 or greater.")

            if n == 1:
                deleted_value = self.head.data
                self.head = self.head.next
                print(f"Deleted node at position 1 with value: {deleted_value}")
                return

            current = self.head
            count = 1
            while current and count < n - 1:
                current = current.next
                count += 1

            if current is None or current.next is None:
                raise IndexError("Index out of range.")

            deleted_value = current.next.data
            current.next = current.next.next
            print(f"Deleted node at position {n} with value: {deleted_value}")

        except IndexError as e:
            print(f"Error: {e}")


if __name__ == "__main__":
    ll = LinkedList()

    # Add nodes
    ll.add_node(10)
    ll.add_node(20)
    ll.add_node(30)
    ll.add_node(40)

    ll.print_list()

    # Delete nodes
    ll.delete_nth_node(2) 
    ll.print_list()

    ll.delete_nth_node(5)  
    ll.delete_nth_node(0) 

    # Delete all nodes
    ll.delete_nth_node(1)
    ll.delete_nth_node(1)
    ll.delete_nth_node(1)
    ll.print_list()

    ll.delete_nth_node(1)
# Out:
# Added head: 10
# Added: 20
# Added: 30
# Added: 40
# Linked List: 10 -> 20 -> 30 -> 40 -> None
# Deleted node at position 2 with value: 20
# Linked List: 10 -> 30 -> 40 -> None
# Error: Index out of range.
# Error: Invalid index. Must be 1 or greater.
# Deleted node at position 1 with value: 10
# Deleted node at position 1 with value: 30
# Deleted node at position 1 with value: 40
# List is empty.
# Error: Cannot delete from an empty list.
